# %%
import pandas as pd

# %%
# Load datasets
# df2 - mostly India
# df3 - only US
df1 = pd.read_csv("./../data/raw/Startups.csv")
# df2 = pd.read_csv("./../data/raw/50_Startups.csv", on_bad_lines='skip', sep = ';')
# df3 = pd.read_csv("./../data/raw/startup data.csv")
df4 = pd.read_csv("./../data/raw/Startups_GitHubDataSet.csv", encoding= 'unicode_escape', sep = ';', on_bad_lines='skip')
df5 = pd.read_csv("./../data/raw/Unicorn_Clean.csv")
# df6 = pd.read_excel('./../data/raw/Tech-startup dataset.xlsx') - it's a mess

# %%
# Clean up the column with Countries
df1 = df1.replace(u'\xa0', u'', regex=True)

# %%
df4.head()
# Out:
#    Unnamed: 0    Company  Valuation ($B) Date Joined        Country  \
# 0           0  Bytedance           140.0  2017-04-07          China
# 1           1     SpaceX           100.3  2012-12-01  United States
# 2           2     Stripe            95.0  2014-01-23  United States
# 3           3     Klarna            45.6  2011-12-12         Sweden
# 4           4      Canva            40.0  2018-01-08      Australia
#
#             City                      Industry  \
# 0        Beijing       Artificial intelligence
# 1      Hawthorne                         Other
# 2  San Francisco                       Fintech
# 3      Stockholm                       Fintech
# 4    Surry Hills  Internet software & services
#
#                        Investor 1               Investor 2  \
# 0           Sequoia Capital China     SIG Asia Investments
# 1                   Founders Fund  Draper Fisher Jurvetson
# 2                 Khosla Ventures         LowercaseCapital
# ...

# %%
# check if Germany is in
df4['Mapping Location'].str.contains('Germany').any()

# %%
# check how many times Germany is inside
df4['Mapping Location'].str.contains('Germany').sum()

# %%
df4['Mapping Location'].unique()
# Out:
# array(['San Francisco - California - USA',
#        'New York City - New York - USA',
#        'Mountain View - California - USA', 'Palo Alto - California - USA',
#        'Venice - California - USA', 'Boulder - Colorado - USA',
#        'Princeton - New Jersey - USA', 'Chicago - Illinois - USA',
#        'Boston - Massachusetts - USA', 'London - United Kingdom',
#        'Toronto - Canada', 'Arlington Heights - Massachusetts - USA',
#        'Walnut - California - USA', 'Redwood Shores - California - USA',
#        'Atherton - California - USA', 'Burlingame - California - USA',
#        'San Jose - California - USA', 'Menlo Park - California - USA',
#        'Sydney - Australia', 'Bothell - Washington - USA',
#        'Berkeley - California - USA', 'Silicon Valley - California - USA',
#        'Rio De Janeiro - Brazil', 'Garden City - New York - USA',
#        'Kitchener - Canada', 'Fayetteville - Arkansas - USA',
#        'Redwood City - California - USA', nan,
# ...

# %%
df5.head()
df5.Country.unique()
# Out:
# array(['China', 'United States', 'Sweden', 'Australia', 'United Kingdom',
#        'Brazil', 'Hong Kong', 'India', 'Indonesia', 'Germany', 'Mexico',
#        'Canada', 'Turkey', 'South Korea', 'Netherlands', 'Israel',
#        'Colombia', 'Belgium', 'Lithuania', 'Estonia', 'France', 'Austria',
#        'Ireland', 'Singapore', 'Vietnam', 'United Arab Emirates',
#        'Switzerland', 'Argentina', 'Spain', 'Japan', 'Luxembourg',
#        'Nigeria', 'Santa Clara', 'Finland', 'Philippines', 'Denmark',
#        'Senegal', 'Bermuda', 'Norway', 'South Africa', 'Chile',
#        'Thailand', 'Malaysia', 'Czech Republic', 'Croatia'], dtype=object)

# %%
# Finding Germany in the datasets 

gf1 = df1[df1['Country'] == 'Germany']
# Out:
#             Company  Valuation Valuation_date                   Industry  \
# 32          Celonis       11.0        June-21                   Software
# 76         Personio        6.3     October-21                   Software
# 91   Trade Republic        5.3         May-21                    Fintech
# 152             N26        3.5        July-19         Financial services
# 177      Contentful        3.0        July-21  Content management system
# 198           Wefox        3.0        June-21                        NaN
#
#      Country
# 32   Germany
# 76   Germany
# 91   Germany
# 152  Germany
# 177  Germany
# 198  Germany

# %%
gf2 = df4[df4['Mapping Location'] =='Berlin - Germany']
gf2
# Out:
#           Company      Satus  Year Founded  Mapping Location  \
# 298  DirectedEdge  Operating        2008.0  Berlin - Germany
#
#                                            Description  \
# 298  Directed Edge provides real-time suggestion li...
#
#                                             Categories  \
# 298  Services, Reviews and Recommendations, Curated...
#
#                             Founders  Y Combinator Year Y Combinator Session  \
# 298  Scott Wheeler, Valentin Hussong               2009               Summer
#
#         Investors Amounts raised in different funding rounds  \
# 298  Y Combinator                                    $15,000
#
#                               Office Address Headquarters (City)  \
# 298  Schlesische Str. 26, Berlin, 10997, DEU              Berlin
#
#     Headquarters (US State) Headquarters (Country)  \
# 298                     NaN                Germany
#
#                                                   Logo  \
# ...

# %%
gf3 = df5[df5['Country'] == 'Germany']
gf3
# Out:
#      Unnamed: 0               Company  Valuation ($B) Date Joined  Country  \
# 33           33               Celonis           11.00  2018-06-26  Germany
# 47           47                   N26            9.23  2019-01-10  Germany
# 86           86              Personio            6.30  2021-01-19  Germany
# 105         105        Trade Republic            5.30  2021-05-20  Germany
# 190         190  Otto Bock HealthCare            3.52  2017-06-24  Germany
# 232         232          FlixMobility            3.00  2019-07-18  Germany
# 246         246            Contentful            3.00  2021-07-28  Germany
# 251         251              Gorillas            3.10  2021-03-25  Germany
# 281         281                 Flink            2.70  2021-12-01  Germany
# 326         326           NuCom Group            2.20  2018-02-22  Germany
# 348         348                 Mambu            2.08  2021-01-06  Germany
# ...
